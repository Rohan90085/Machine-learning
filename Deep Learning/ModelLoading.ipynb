# %%
import tensorflow as tf
import numpy as np
model=tf.keras.models.load_model('my_model.keras')
model.summary()
model.predict
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_21 (Dense)                │ (None, 16)             │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 3)              │            27 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 731 (2.86 KB)
#  Trainable params: 243 (972.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 488 (1.91 KB)
# <bound method TensorFlowTrainer.predict of <Sequential name=sequential_7, built=True>>

# %%
new_flower = np.array([[5.1, 3.5, 1.4, 0.2]])
probabilities = model.predict(new_flower)
print(probabilities)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# [[3.3476788e-09 9.5166820e-01 4.8331771e-02]]

# %%
predicted_class = np.argmax(probabilities, axis=1)[0]

# Class label mapping for the Iris dataset
class_names = ['Setosa', 'Versicolor', 'Virginica']

print("Prediction probabilities:",probabilities)
print("Predicted Class:", class_names[predicted_class])
# Out:
# Prediction probabilities: [[3.3476788e-09 9.5166820e-01 4.8331771e-02]]
# Predicted Class: Versicolor
