# %%
import cv2

# %%
img=cv2.imread("Ganesha.png")
cv2.imshow("Ganesha",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2.imshow("ganesha",gray)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.imwrite("Gaensha_gray.png",gray)
# Out:
# True
