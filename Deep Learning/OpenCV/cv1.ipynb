# %%
import cv2

# %%
img=cv2.imread('Ganesha.png')
print(img.shape)
print(img)
cv2.imshow("Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite('Ganeshac.png',img)
print('shape:',img.shape)
# Out:
# shape: (610, 633, 3)
