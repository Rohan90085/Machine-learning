# %%
import cv2
img=cv2.imread("Photos\Ganesha.png")
cv2.imshow("image",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.putText(img,"jai Gnaesha",(100,100),cv2.FONT_HERSHEY_SIMPLEX,1,(0,255,0),2)
cv2.imshow("image",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
cap=cv2.VideoCapture(0)
while True:
    ret,frame=cap.read()
    cv2.imshow("video",frame)
    if cv2.waitKey(1)&0xFF==ord('q'):
        break
    cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[9], line 5
#       3 while True:
#       4     ret,frame=cap.read()
# ----> 5     cv2.imshow("video",frame)
#       6     if cv2.waitKey(1)&0xFF==ord('q'):
#       7         break
#
# error: OpenCV(5.0.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:951: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'

# %%
import cv2
import matplotlib.pyplot as plt

cap = cv2.VideoCapture(0)
ret, frame = cap.read()
cap.release()

frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
cv2.imwrite("captured_image.jpg", frame)
plt.imshow(frame)
plt.axis("off")
plt.show()

# %%
import cv2
img=cv2.imread("Photos\Ganesha.png")
txt=cv2.putText(img,"jai ganesha",(200,500),cv2.FONT_HERSHEY_SIMPLEX,1,(0,255,0),2)
cv2.imshow("output.jpg", txt)
cv2.waitKey(0)
cv2.destroyAllWindows()
