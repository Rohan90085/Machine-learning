# %%
import cv2

# %%
print("enter the image name which is have in your directory:")
pht=str(input())
img=cv2.imread(pht)
cv2.imshow("image",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
#image saving
cv2.imwrite('C:\\Users\\Abhilash PH\\Desktop\\Machine-learning\\Deep Learning\\OpenCV\\Photos\\user_image.png', img)
# Out:
# enter the image name which is have in your directory:
# False
