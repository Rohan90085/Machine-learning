# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
from xgboost import XGBRegressor

df = pd.read_csv('Final_Marks_Data.csv')

df.drop('Student_ID', axis=1, inplace=True)

X = df[['Attendance (%)',
        'Internal Test 1 (out of 40)',
        'Internal Test 2 (out of 40)',
        'Assignment Score (out of 10)',
        'Daily Study Hours']]

y = df['Final Exam Marks (out of 100)']

xt, xtst, yt, ytst = train_test_split(
    X, y, test_size=0.2
)

model = LinearRegression()
model.fit(xt, yt)
modelxgb=XGBRegressor(n_estimators=100,
learning_rate=0.1,max_depth=3,subsample=0.8,colsample_bytree=0.4)
modelxgb.fit(X,y)

# Predictions
ypred = model.predict(xtst)

# Metrics
mae = mean_absolute_error(ytst, ypred)
mse = mean_squared_error(ytst, ypred)
rmse = np.sqrt(mse)
print(xtst.iloc[0])
print("tst:",ytst.iloc[0])
print("\nRegression:", model.predict(xtst)[0])
print("XGB:", modelxgb.predict(xtst)[0])
print("MAE :", mae)
print("MSE :", mse)
print("RMSE:", rmse)
print("R² Score:", model.score(xtst, ytst))
# Out:
# Attendance (%)                  88
# Internal Test 1 (out of 40)     33
# Internal Test 2 (out of 40)     35
# Assignment Score (out of 10)     7
# Daily Study Hours                3
# Name: 567, dtype: int64
# tst: 70
#
# Regression: 68.79841283851836
# XGB: 68.79166
# MAE : 3.5984192876145915
# MSE : 20.474452083923453
# RMSE: 4.524870394157545
# R² Score: 0.841580744725455
