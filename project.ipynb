# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
from xgboost import XGBRegressor

df = pd.read_csv('Final_Marks_Data.csv')

df.drop('Student_ID', axis=1, inplace=True)

X = df[['Attendance (%)',
        'Internal Test 1 (out of 40)',
        'Internal Test 2 (out of 40)',
        'Assignment Score (out of 10)',
        'Daily Study Hours']]

y = df['Final Exam Marks (out of 100)']

xt, xtst, yt, ytst = train_test_split(
    X, y, test_size=0.2
)

model = LinearRegression()
model.fit(xt, yt)
modelxgb=XGBRegressor(n_estimators=100,
learning_rate=0.1,max_depth=3,subsample=0.8,colsample_bytree=0.4)
modelxgb.fit(X,y)

# Predictions
ypred = model.predict(xtst)

# Metrics
mae = mean_absolute_error(ytst, ypred)
mse = mean_squared_error(ytst, ypred)
rmse = np.sqrt(mse)
print(xtst.iloc[0])
print("\ntst:",ytst.iloc[0])
print("Regression:", model.predict(xtst)[0])
print("XGB:", modelxgb.predict(xtst)[0])
print("\nMAE :", mae)
print("MSE :", mse)
print("RMSE:", rmse)
print("R² Score:", model.score(xtst, ytst))
# Out:
# Attendance (%)                  86
# Internal Test 1 (out of 40)     34
# Internal Test 2 (out of 40)     40
# Assignment Score (out of 10)     9
# Daily Study Hours                2
# Name: 1161, dtype: int64
#
# tst: 78
# Regression: 73.39852055075718
# XGB: 74.602394
#
# MAE : 3.32804397903219
# MSE : 18.3694497749995
# RMSE: 4.285959609585641
# R² Score: 0.8593239284184745
